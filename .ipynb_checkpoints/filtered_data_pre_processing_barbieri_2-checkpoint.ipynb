# %%
import emoji 
import json
import datetime
import re
from collections import Counter
import timeit
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import ijson

file_path = "data_tweets_with_emoji_json.txt"

# %%
### läd Datei
def get_tweets(filename):
    for line in open(filename, encoding='utf-8'):
        yield json.loads(line)
        # yield print(twitter.Status.NewFromJsonDict(json.loads(line)))


def get_full_tweets(filename):
    for line in open(filename, encoding='utf-8'):
        yield json.loads(line)

# dekstop
#data = get_full_tweets("C:\\MSc\\data_tweets_with_emoji_json.txt")

# mobile
data = get_full_tweets("C:\\Users\\Wilm\\Documents\\GitHub\\MSc\\Barbieri Korpus\\data_tweets_with_emoji_json.txt")

# %%
df = pd.DataFrame(data, columns=['id_str','text','in_reply_to_user_id_str'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392017 entries, 0 to 392016
# Data columns (total 3 columns):
# id_str                     392017 non-null object
# text                       392017 non-null object
# in_reply_to_user_id_str    10398 non-null object
# dtypes: object(3)
# memory usage: 9.0+ MB

# %%
def extract_chars(my_str):     
    return ''.join([c for c in my_str if not(c in emoji.UNICODE_EMOJI)])

def anonymize_username(my_str):
    anonymized_text = ['@username' if x.startswith('@') else x for x in list(my_str.split())]
    return ' '.join(anonymized_text)

def anonymize_hashtag(my_str): 
    return ' '.join(['#hashtag' if x.startswith('#') else x for x in list(my_str.split())])

def delete_links(my_str): 
    return ' '.join(['' if x.startswith('https') else x for x in list(my_str.split())])
# to do: hashtags und links entfernen

df_clean_text = df['text'].apply(lambda x: delete_links(anonymize_hashtag(anonymize_username(extract_chars(x)))))

# %%
def extract_emojis(my_str):
    return ''.join(c for c in my_str if c in emoji.UNICODE_EMOJI)

df_extr_emojis = df['text'].apply(lambda x: extract_emojis(x))

# %%
# unhide the strings in jupyter notebook
pd.options.display.max_rows
pd.set_option('display.max_colwidth', -1)

# assign all new functions to df

new_df = df.assign(clean_text = df_clean_text, extr_emojis = df_extr_emojis) # , langid = df_langid
new_df.head()
# Out:
#                id_str  \
# 0  689736119580233728
# 1  812015924374974464
# 2  801647284685373440
# 3  781871095351828480
# 4  714690241370660865
#
#                                                                                                                   text  \
# 0  LoL 😂 @ West Covina, California https://t.co/ylNndaC0ls
# 1  Things got a little festive at the office 🎄#christmas2016 @ RedRock… https://t.co/mE8HmWpJ40
# 2  Step out and explore. #❤️ @ Ellis Island Cafe https://t.co/mVOVCPXQRQ
# 3  📸 @vinniehatestyle @ Cathedral Preparatory School https://t.co/SNLPazrrk2
# 4  RuPaul's Drag Race bingo fun. Drag Queens be SEXY! #rupaulsdragrace @fioelly abwyman 😘 #la… https://t.co/VC2M2uWmlp
#
#   in_reply_to_user_id_str  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
#
#                                                                                 clean_text  \
# 0  LoL @username West Covina, California
# 1  Things got a little festive at the office #hashtag @username RedRock…
# 2  Step out and explore. #hashtag @username Ellis Island Cafe
# 3  @username @username Cathedral Preparatory School
# 4  RuPaul's Drag Race bingo fun. Drag Queens be SEXY! #hashtag @username abwyman #hashtag
#
#   extr_emojis
# 0  😂
# 1  🎄
# 2  ❤
# 3  📸
# 4  😘

# %%
# rows only with emoji

# len(df_emoji_rows.index) = 194625

df_emoji_rows = new_df[new_df.extr_emojis != '']
df_emoji_rows.head()
# Out:
#                id_str  \
# 0  689736119580233728
# 1  812015924374974464
# 2  801647284685373440
# 3  781871095351828480
# 4  714690241370660865
#
#                                                                                                                   text  \
# 0  LoL 😂 @ West Covina, California https://t.co/ylNndaC0ls
# 1  Things got a little festive at the office 🎄#christmas2016 @ RedRock… https://t.co/mE8HmWpJ40
# 2  Step out and explore. #❤️ @ Ellis Island Cafe https://t.co/mVOVCPXQRQ
# 3  📸 @vinniehatestyle @ Cathedral Preparatory School https://t.co/SNLPazrrk2
# 4  RuPaul's Drag Race bingo fun. Drag Queens be SEXY! #rupaulsdragrace @fioelly abwyman 😘 #la… https://t.co/VC2M2uWmlp
#
#   in_reply_to_user_id_str  \
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
#
#                                                                                 clean_text  \
# 0  LoL @username West Covina, California
# 1  Things got a little festive at the office #hashtag @username RedRock…
# 2  Step out and explore. #hashtag @username Ellis Island Cafe
# 3  @username @username Cathedral Preparatory School
# 4  RuPaul's Drag Race bingo fun. Drag Queens be SEXY! #hashtag @username abwyman #hashtag
#
#   extr_emojis
# 0  😂
# 1  🎄
# 2  ❤
# 3  📸
# 4  😘

# %%
# percantage of TOP 20 Emoji

series_emoji_top20 = df_emoji_rows.extr_emojis.value_counts().head(20)
df_emoji_top20 = series_emoji_top20.to_frame()
df_emoji_top20['emoji'] = df_emoji_top20.index
df_emoji_top20['Anzahl'] = df_emoji_top20['extr_emojis']
df_emoji_top20 = df_emoji_top20.drop(columns = 'extr_emojis')
df_emoji_top20.reset_index(inplace=True)
df_emoji_top20 = df_emoji_top20.drop(columns = 'index')
df_emoji_top20['Prozent'] = df_emoji_top20['Anzahl']/df_emoji_top20['Anzahl'].sum() * 100
df_emoji_top20_transpose = df_emoji_top20.transpose()
df_emoji_top20
# Out:
#    emoji  Anzahl    Prozent
# 0   ❤     93270   23.792336
# 1   😍     39388   10.047523
# 2   😂     26317   6.713229
# 3   💕     24849   6.338756
# 4   😊     21511   5.487262
# 5   😎     20055   5.115850
# 6   📷     16379   4.178135
# 7   💙     14751   3.762847
# 8   ✨     14616   3.728410
# 9   😘     13449   3.430719
# 10  📸     13414   3.421790
# 11  😉     13393   3.416433
# 12  ☀     12532   3.196800
# 13  😜     11775   3.003696
# 14  🔥     11705   2.985840
# 15  🎄     11438   2.917731
# 16  😁     11301   2.882783
# 17  💜     10965   2.797073
# 18  💯     10909   2.782787

# %%
#df_emoji_top20['Anzahl'].sum()
df_emoji_top20['Prozent'].sum()
# Out:
# 100.0

# %%
import matplotlib
# Say, "the default sans-serif font is COMIC SANS"
matplotlib.rcParams['font.sans-serif'] = "Segoe UI Emoji"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"

# %%
# vorkommen aller emoji
df_emoji_rows.extr_emojis.value_counts().head(20).plot.bar()
plt.xlabel('TOP 19 Emoji')
plt.ylabel('Anzahl')

plt.savefig('df_barbieri_vorkommen_emoji_alle.pdf', bbox_inches='tight')

# %%
# POS Tagger "TweeboParser" 

# pre processing for POS Tagger
# df_emoji_rows.text.to_csv(r'barbieri_tweets_text.txt', header=None, index=None, mode='a', sep=',')

# creating dataframe
df_pos = pd.read_csv("C:\\Users\\Wilm\\Documents\\GitHub\\MSc\\ark-tweet-nlp-0.3.2\\barbieri_POS_tagged_tweets.txt", sep='\t')

# %%
df_pos.columns = ['raw_text', 'POS', 'likelihood', 'tweet_text_2']
df_pos = df_pos.drop(columns = 'tweet_text_2')


df_pos_emo_end = df_pos[df_pos['POS'].str.endswith('E',na = False)]
# counting rows endswith emoji : len(df_pos_emo_end.index) == 36428
df_pos_emo_end.head()
# Out:
#                                                          raw_text  \
# 47   Thank God 4 another day !! 😊
# 49   I love you guys . ❤ ️
# 137  😍
# 152  @DylanMcDermott @MaggieQ he's beautiful your Super Dog !!! 😍
# 221  I wanna see my brothers make it ❤ ️
#
#                    POS  \
# 47   V ^ P D N , E
# 49   O V O N , E E
# 137  E
# 152  @ @ L A D ^ ^ , E
# 221  O V V D N V O E E
#
#                                                          likelihood
# 47   0,7614 0,9391 0,8230 0,9905 0,9984 0,9960 0,8398
# 49   0,9967 0,9995 0,9872 0,9800 0,9983 0,9237 0,6544
# 137  0,7989
# 152  0,9989 0,9977 0,9852 0,9927 0,8908 0,6657 0,7339 0,9920 0,7782
# 221  0,9976 0,9993 0,9996 0,9994 0,9944 0,9945 0,9061 0,4534 0,5718

# %%
# finding the last word category befor emoji 

def last_word_category(my_string):
    s = list(my_string.replace(" ",""))
    categories = []
    index = 0
    
    while index != len(s):
    #print(s[index])
        if s[index] == 'E':
            category = s[index-1]
            categories.append(category)
        index += 1
    return ' '.join(categories)

df_last_word_category = df_pos_emo_end['POS'].apply(lambda x: last_word_category(x))

# %%
df_pos_emo_end = df_pos_emo_end.assign(last_word_category = df_last_word_category)

df_pos_emo_end.head()
# Out:
#                                                          raw_text  \
# 47   Thank God 4 another day !! 😊
# 49   I love you guys . ❤ ️
# 137  😍
# 152  @DylanMcDermott @MaggieQ he's beautiful your Super Dog !!! 😍
# 221  I wanna see my brothers make it ❤ ️
#
#                    POS  \
# 47   V ^ P D N , E
# 49   O V O N , E E
# 137  E
# 152  @ @ L A D ^ ^ , E
# 221  O V V D N V O E E
#
#                                                          likelihood  \
# 47   0,7614 0,9391 0,8230 0,9905 0,9984 0,9960 0,8398
# 49   0,9967 0,9995 0,9872 0,9800 0,9983 0,9237 0,6544
# 137  0,7989
# 152  0,9989 0,9977 0,9852 0,9927 0,8908 0,6657 0,7339 0,9920 0,7782
# 221  0,9976 0,9993 0,9996 0,9994 0,9944 0,9945 0,9061 0,4534 0,5718
#
#     last_word_category
# 47   ,
# 49   , E
# 137  E
# 152  ,
# 221  O E

# %%
# last word category to emoji

df_pos_emo_end = df_pos_emo_end[df_pos_emo_end.last_word_category.str.len() == 1]
df_pos_emo_end.last_word_category.value_counts().head(20)
# Out:
# ,    1819
# N    1453
# A    391
# O    335
# ^    317
# R    311
# V    290
# E    199
# #    126
# @    106
# P    76
# !    74
# $    42
# G    30
# T    29
# D    23
# U    7
# ~    4
# Z    3
# &    2
# Name: last_word_category, dtype: int64

# %%
df_pos_emo_end.last_word_category.value_counts().head(20).sum()
# Out:
# 5637

# %%
# pie chart percentag of word categories

labels = 'Interpunktion', 'Nomen', 'Adjektiv', 'Pronomen', 'Eigennamen', 'weitere'
fracs = [1819, 1453, 391 , 335 , 317 , 1322]
plt.pie(fracs, labels = labels, autopct='%.2f')
plt.axis('equal') 
plt.savefig('df_barbieri_last_word_category.pdf', bbox_inches='tight')
